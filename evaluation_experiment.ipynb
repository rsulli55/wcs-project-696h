# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import matplotlib.ticker as ticker
import matplotlib.cm

import wcs

# %%
LANGS_TO_CHECK = [16, 17, 20, 32, 36]
HOLD_OUT_FRACTIONS = [0.0, 0.2, 0.4, 0.6, 0.8]

# %%
full_word_counts = {}
simple_models = {}
threshold = 5
color_dists = wcs.all_pairwise_color_distances()
adjacency_dict = wcs.build_adjacency_dict(color_dists, threshold)
for lang in LANGS_TO_CHECK:
    full_word_counts[lang] = wcs.build_word_count(lang)
    simple_models[lang] = wcs.build_simple_model(full_word_counts[lang])

# %%
num_trials = 10
neighbor_weight = 3
burn_in_iterations = 15
num_restarts = 10
num_to_generate = 3
## running evaulation experiment
for lang in LANGS_TO_CHECK:
    print(f"Running Evaluation for language {lang}")
    print(f"{20*'-'}")
    
    for fraction in HOLD_OUT_FRACTIONS:
        print(f"Building MRF model with {fraction}% held out")
        ave_divergences = np.zeros(num_trials)
        for trial in range(num_trials):
            # print(f"\tOn trial {trial+1}")
            held_out_speakers = wcs.build_rand_set_of_speakers(lang, fraction)
            wc, ho = wcs.build_held_out_word_count(lang, held_out_speakers)
            samples = wcs.mrf_sampler(wc, adjacency_dict, neighbor_weight, num_restarts,
                                  burn_in_iterations, num_to_generate)
            mrf_model = wcs.build_mrf_model_from_samples(samples)
            
            divs = wcs.compute_KL_divs(mrf_model, simple_models[lang])
            ave_divergences[trial] = np.mean(divs)
            
        # print(f"{20*'-'}")
        print(f"\nFor lang {lang} and hold out frac {fraction}, average divergences = {ave_divergences}")
        print(f"\tThe mean of these is {np.mean(ave_divergences)} and std dev {np.std(ave_divergences)}")
        print(f"{20*'-'}")
# Out:
# Running Evaluation for language 16
# --------------------
# Building MRF model with 0.0% held out
#
# For lang 16 and hold out frac 0.0, average divergences = [0.3893012  0.38680586 0.38763276 0.39231714 0.38519376 0.38839466
#  0.38674512 0.38392609 0.39023779 0.39049819]
# 	The mean of these is 0.38810525757645886 and std dev 0.002433756937987399
# --------------------
# Building MRF model with 0.2% held out
#
# For lang 16 and hold out frac 0.2, average divergences = [0.38878678 0.40055945 0.37957256 0.38765108 0.39747663 0.38636222
#  0.3873325  0.3855244  0.38019146 0.3881079 ]
# 	The mean of these is 0.38815649824536885 and std dev 0.006239433345521656
# --------------------
# Building MRF model with 0.4% held out
#
# For lang 16 and hold out frac 0.4, average divergences = [0.3848537  0.39255305 0.38127523 0.39189618 0.35137301 0.37793546
#  0.38637255 0.39589407 0.39878397 0.39443453]
# 	The mean of these is 0.385537176270092 and std dev 0.01302256125970056
# --------------------
# Building MRF model with 0.6% held out
#
# For lang 16 and hold out frac 0.6, average divergences = [0.38668508 0.38045087 0.36186429 0.4262563  0.46357611 0.36169908
#  0.37190939 0.37119771 0.36869366 0.4620722 ]
# 	The mean of these is 0.3954404685291934 and std dev 0.03802087515212066
# --------------------
# Building MRF model with 0.8% held out
#
# For lang 16 and hold out frac 0.8, average divergences = [0.3915032  0.41779668 0.35513812 0.54249194 0.59411377 0.3856816
#  0.43284953 0.46640968 0.36835491 0.31906224]
# 	The mean of these is 0.427340166881579 and std dev 0.08133723270316827
# --------------------
# Running Evaluation for language 17
# --------------------
# Building MRF model with 0.0% held out
#
# For lang 17 and hold out frac 0.0, average divergences = [0.48349604 0.49712077 0.4847587  0.49546142 0.48837986 0.49935389
#  0.49147681 0.4974985  0.48957395 0.49068425]
# 	The mean of these is 0.4917804185383857 and std dev 0.005174791284859865
# --------------------
# Building MRF model with 0.2% held out
#
# For lang 17 and hold out frac 0.2, average divergences = [0.49799237 0.50084358 0.47744433 0.47680121 0.48302398 0.48788171
#  0.49113409 0.4948833  0.49745094 0.48560703]
# 	The mean of these is 0.4893062561546313 and std dev 0.008133884365605516
# --------------------
# Building MRF model with 0.4% held out
#
# For lang 17 and hold out frac 0.4, average divergences = [0.46298457 0.47641365 0.48762585 0.44058452 0.48898571 0.48502287
#  0.45789896 0.47035734 0.4803936  0.47337974]
# 	The mean of these is 0.47236467922534053 and std dev 0.014361516597574417
# --------------------
# Building MRF model with 0.6% held out
#
# For lang 17 and hold out frac 0.6, average divergences = [0.46851719 0.45095959 0.4404707  0.48870256 0.47123507 0.47093388
#  0.60334933 0.471474   0.49222521 0.49156668]
# 	The mean of these is 0.4849434219868213 and std dev 0.04254308118526876
# --------------------
# Building MRF model with 0.8% held out
#
# For lang 17 and hold out frac 0.8, average divergences = [0.51525032 0.51263093 0.56336378 0.59446783 0.57264373 0.5367849
#  0.72578365 0.56380715 0.61757044 0.96547871]
# 	The mean of these is 0.6167781440928108 and std dev 0.13005114154267472
# --------------------
# Running Evaluation for language 20
# --------------------
# Building MRF model with 0.0% held out
#
# For lang 20 and hold out frac 0.0, average divergences = [0.29427709 0.309046   0.3332857  0.3397568  0.33865764 0.3386273
#  0.33186124 0.32018883 0.33424168 0.31532602]
# 	The mean of these is 0.32552682841519215 and std dev 0.014503520223790542
# --------------------
# Building MRF model with 0.2% held out
#
# For lang 20 and hold out frac 0.2, average divergences = [0.3392167  0.33606663 0.30924888 0.31921341 0.32343037 0.36672122
#  0.35132391 0.3037571  0.31009313 0.36256428]
# 	The mean of these is 0.3321635621486971 and std dev 0.02147934806024819
# --------------------
# Building MRF model with 0.4% held out
#
# For lang 20 and hold out frac 0.4, average divergences = [0.39141808 0.39619293 0.3118588  0.36009374 0.43446066 0.30547462
#  0.38308423 0.36634686 0.33285366 0.32911565]
# 	The mean of these is 0.36108992285356517 and std dev 0.03922252784616232
# --------------------
# Building MRF model with 0.6% held out
#
# For lang 20 and hold out frac 0.6, average divergences = [0.49215647 0.61580486 0.6097674  0.47980374 0.75766695 0.46242323
#  0.43255636 0.56600561 0.61048428 0.70273447]
# 	The mean of these is 0.5729403358727645 and std dev 0.10136262949759124
# --------------------
# Building MRF model with 0.8% held out
#
# For lang 20 and hold out frac 0.8, average divergences = [0.78928539 0.58534975 0.59369245 0.8945353  0.67998955 0.52144156
#  1.13554145 1.50198065 0.50312165 0.79373354]
# 	The mean of these is 0.7998671301841347 and std dev 0.29719140738911837
# --------------------
# Running Evaluation for language 32
# --------------------
# Building MRF model with 0.0% held out
#
# For lang 32 and hold out frac 0.0, average divergences = [0.40091593 0.40405103 0.39912697 0.40323047 0.40420559 0.40220701
#  0.40299337 0.40592254 0.40350757 0.41270857]
# 	The mean of these is 0.40388690567500046 and std dev 0.00343180831925114
# --------------------
# Building MRF model with 0.2% held out
#
# For lang 32 and hold out frac 0.2, average divergences = [0.41077119 0.40525543 0.40942761 0.39370419 0.39437962 0.39088806
#  0.39404272 0.41935146 0.41191022 0.39208166]
# 	The mean of these is 0.4021812171772961 and std dev 0.00976583729812013
# --------------------
# Building MRF model with 0.4% held out
#
# For lang 32 and hold out frac 0.4, average divergences = [0.40878522 0.4037519  0.37524711 0.39719422 0.38309489 0.39294973
#  0.41155437 0.3906314  0.41713489 0.40674843]
# 	The mean of these is 0.39870921566881484 and std dev 0.012613813715864038
# --------------------
# Building MRF model with 0.6% held out
#
# For lang 32 and hold out frac 0.6, average divergences = [0.36780638 0.40913959 0.38664901 0.39692084 0.37405927 0.46464406
#  0.36899233 0.47414998 0.40274509 0.36196733]
# 	The mean of these is 0.4007073873335637 and std dev 0.03750757111250374
# --------------------
# Building MRF model with 0.8% held out
#
# For lang 32 and hold out frac 0.8, average divergences = [0.5091872  0.36560476 0.31773325 0.4671881  0.53786679 0.58509253
#  0.50579083 0.47259915 0.51856513 0.42788982]
# 	The mean of these is 0.47075175500302 and std dev 0.07674189846230267
# --------------------
# Running Evaluation for language 36
# --------------------
# Building MRF model with 0.0% held out
#
# For lang 36 and hold out frac 0.0, average divergences = [0.13858633 0.1362481  0.13946027 0.13646154 0.14363717 0.13973136
#  0.13961155 0.13965227 0.13923849 0.14148152]
# 	The mean of these is 0.13941085911940157 and std dev 0.0020436275517435247
# --------------------
# Building MRF model with 0.2% held out
#
# For lang 36 and hold out frac 0.2, average divergences = [0.13811628 0.13431292 0.14460372 0.13573303 0.14013968 0.14834037
#  0.1451807  0.1462249  0.14012999 0.13894278]
# 	The mean of these is 0.14117243725891712 and std dev 0.004448048510270929
# --------------------
# Building MRF model with 0.4% held out
#
# For lang 36 and hold out frac 0.4, average divergences = [0.12865893 0.13292098 0.13598218 0.14951397 0.13830488 0.14254572
#  0.13906237 0.13953363 0.14095454 0.1343544 ]
# 	The mean of these is 0.13818315981387247 and std dev 0.005437063857695847
# --------------------
# Building MRF model with 0.6% held out
#
# For lang 36 and hold out frac 0.6, average divergences = [0.12780835 0.15686522 0.13540673 0.14283756 0.12420027 0.13663054
#  0.13397268 0.13391574 0.14137847 0.12802489]
# 	The mean of these is 0.13610404326150444 and std dev 0.00888860030096983
# --------------------
# Building MRF model with 0.8% held out
#
# For lang 36 and hold out frac 0.8, average divergences = [0.14385745 0.11055377 0.19633415 0.13144877 0.13633227 0.22819519
#  0.13122731 0.13106969 0.11808534 0.14853289]
# 	The mean of these is 0.14756368307983542 and std dev 0.03472483771871131
# --------------------
